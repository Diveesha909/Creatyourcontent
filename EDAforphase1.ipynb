# %% [markdown]
# <a href="https://colab.research.google.com/github/Diveesha909/Creatyourcontent/blob/main/EDAforphase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("atharvasoundankar/viral-social-media-trends-and-engagement-analysis")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 225k/225k [00:00<00:00, 65.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/atharvasoundankar/viral-social-media-trends-and-engagement-analysis/versions/2

# %%
# !git clone https://github.com/Diveesha909/Creatyourcontent.git
# Out:
# Cloning into 'Creatyourcontent'...
# remote: Enumerating objects: 35, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 35 (delta 16), reused 4 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (35/35), 708.18 KiB | 6.32 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
import json
with open("/content/Creatyourcontent/synthetic_influencers.json", "r") as f:
  data = json.load(f)

# %%
import pandas as pd

df = pd.DataFrame(data)
display(df.head())
# Out:
#     influencer_id              username          niche  followers_start  \
# 0  influencer_001      lifestyle_star_1      Lifestyle            54209
# 1  influencer_002      lifestyle_star_2      Lifestyle            64085
# 2  influencer_003        fitness_star_3        Fitness            51051
# 3  influencer_004        fitness_star_4        Fitness            26319
# 4  influencer_005  entertainment_star_5  Entertainment            69723
#
#    monthly_follower_growth_pct  avg_engagement_rate  post_count  \
# 0                        -0.78               0.0617          12
# 1                         9.11               0.0632           8
# 2                         5.19               0.0576           8
# 3                         0.82               0.0494          12
# 4                         2.53               0.0553          14
#
#                                                posts
# 0  [{'post_id': 'influencer_001_post_1', 'caption...
# ...

# %%
import os

path = "/root/.cache/kagglehub/datasets/atharvasoundankar/viral-social-media-trends-and-engagement-analysis/versions/2"
print(os.listdir(path))
# Out:
# ['Viral_Social_Media_Trends.csv', 'Cleaned_Viral_Social_Media_Trends.csv']

# %%
# !mkdir -p /content/kaggle_data
# !mv /root/.cache/kagglehub/datasets/atharvasoundankar/viral-social-media-trends-and-engagement-analysis/versions/2/* /content/kaggle_data/

# %%
! pwd
# !ls
# !ls /content/kaggle_data
# Out:
# /content
# Creatyourcontent  kaggle_data  sample_data
# Cleaned_Viral_Social_Media_Trends.csv  Viral_Social_Media_Trends.csv

# %%
import pandas as pd

kaggle_df = pd.read_csv('/content/kaggle_data/Cleaned_Viral_Social_Media_Trends.csv')

display(kaggle_df.head())
# Out:
#   Post_ID   Post_Date   Platform     Hashtag Content_Type     Region    Views  \
# 0  Post_1  2022-01-13     TikTok  #Challenge        Video         UK  4163464
# 1  Post_2  2022-05-13  Instagram  #Education       Shorts      India  4155940
# 2  Post_3  2022-01-07    Twitter  #Challenge        Video     Brazil  3666211
# 3  Post_4  2022-12-05    YouTube  #Education       Shorts  Australia   917951
# 4  Post_5  2023-03-23     TikTok      #Dance         Post     Brazil    64866
#
#     Likes  Shares  Comments Engagement_Level
# 0  339431   53135     19346             High
# 1  215240   65860     27239           Medium
# 2  327143   39423     36223           Medium
# 3  127125   11687     36806              Low
# 4  171361   69581      6376           Medium

# %%
kaggle_df.describe()
# Out:
#               Views          Likes        Shares      Comments
# count  5.000000e+03    5000.000000   5000.000000   5000.000000
# mean   2.494066e+06  251475.029800  50519.562000  24888.393800
# std    1.459490e+06  144349.583384  29066.362671  14284.504319
# min    1.266000e+03     490.000000     52.000000     18.000000
# 25%    1.186207e+06  126892.250000  25029.000000  12305.250000
# 50%    2.497373e+06  249443.000000  50839.500000  25004.000000
# 75%    3.759781e+06  373970.750000  75774.250000  37072.750000
# max    4.999430e+06  499922.000000  99978.000000  49993.000000

# %%
df.describe()
# Out:
#        followers_start  monthly_follower_growth_pct  avg_engagement_rate  \
# count        20.000000                    20.000000            20.000000
# mean      48118.800000                     2.937000             0.056925
# std       22446.930998                     2.735602             0.009029
# min        6351.000000                    -0.780000             0.035500
# 25%       26220.500000                     0.765000             0.049250
# 50%       54396.000000                     2.585000             0.059500
# 75%       58986.750000                     4.500000             0.062450
# max       95645.000000                     9.110000             0.077100
#
#        post_count
# count   20.000000
# mean    11.550000
# std      2.543826
# min      8.000000
# 25%      9.750000
# 50%     11.500000
# 75%     14.000000
# max     15.000000

# %% [markdown]
# Kaggle dataset has 5000 data entries, whereas synthetic dataset has only 20. The discrepancy between the number of data entries between the dataset could cause inaccuracies when creating models.

# %%
kaggle_df['Hashtag'].value_counts()
# Out:
# Hashtag
# #Fitness      536
# #Education    525
# #Challenge    507
# #Comedy       505
# #Dance        496
# #Music        493
# #Tech         491
# #Fashion      487
# #Viral        481
# #Gaming       479
# Name: count, dtype: int64

# %% [markdown]
# In the frequency table of Hashtag column from the Kaggle dataset, we can see that Fitness, Education, and Challenge are the most common hashtags used.
#
# **Hashtags for entertainment:** Comedy, Dance, and Challenge
#
# **Hashtags for lifestyle:** Education and Fashion
#
# **Hashtags for fitness:** Fitness

# %%
kaggle_df_fitness = kaggle_df[kaggle_df['Hashtag'] == '#Fitness']

# %%
kaggle_df_lifestyle = kaggle_df[(kaggle_df['Hashtag'] == '#Education') | (kaggle_df['Hashtag'] == '#Fashion')]

# %%
kaggle_df_entertainment = kaggle_df[(kaggle_df['Hashtag'] == '#Comedy') | (kaggle_df['Hashtag'] == '#Dance') | (kaggle_df['Hashtag'] == '#Challenge')]

# %%
kaggle_df_fitness.head()
# Out:
#     Post_ID   Post_Date Platform   Hashtag Content_Type     Region    Views  \
# 13  Post_14  2022-11-08  YouTube  #Fitness         Reel      Japan  1633015
# 53  Post_54  2023-09-17  Twitter  #Fitness         Reel     Canada   392337
# 55  Post_56  2023-08-25  YouTube  #Fitness        Tweet  Australia  3934991
# 68  Post_69  2022-01-20  Twitter  #Fitness        Tweet        USA   581577
# 69  Post_70  2022-02-05  YouTube  #Fitness        Tweet  Australia  4226427
#
#      Likes  Shares  Comments Engagement_Level
# 13  312907   45774     30725             High
# 53  332566   43169     45161           Medium
# 55  389693   81891     32967           Medium
# 68  341805   67524       485             High
# 69  421149   53769     27804           Medium

# %%
kaggle_df_lifestyle.head()
# Out:
#     Post_ID   Post_Date   Platform     Hashtag Content_Type     Region  \
# 1    Post_2  2022-05-13  Instagram  #Education       Shorts      India
# 3    Post_4  2022-12-05    YouTube  #Education       Shorts  Australia
# 8    Post_9  2022-09-01    Twitter  #Education  Live Stream      India
# 18  Post_19  2022-05-08     TikTok    #Fashion         Post        USA
# 19  Post_20  2023-04-24    YouTube  #Education        Tweet         UK
#
#       Views   Likes  Shares  Comments Engagement_Level
# 1   4155940  215240   65860     27239           Medium
# 3    917951  127125   11687     36806              Low
# 8   2169523  496078   96041     30174           Medium
# 18  3461154  165335   50077     19505              Low
# 19  3143932  298685   84720     37162              Low

# %%
kaggle_df_entertainment.head()
# Out:
#   Post_ID   Post_Date   Platform     Hashtag Content_Type     Region    Views  \
# 0  Post_1  2022-01-13     TikTok  #Challenge        Video         UK  4163464
# 2  Post_3  2022-01-07    Twitter  #Challenge        Video     Brazil  3666211
# 4  Post_5  2023-03-23     TikTok      #Dance         Post     Brazil    64866
# 5  Post_6  2022-11-23  Instagram  #Challenge       Shorts  Australia  1323566
# 6  Post_7  2022-06-09    YouTube     #Comedy        Tweet      Japan   627233
#
#     Likes  Shares  Comments Engagement_Level
# 0  339431   53135     19346             High
# 2  327143   39423     36223           Medium
# 4  171361   69581      6376           Medium
# 5  136282   86979     47129              Low
# 6   84121   97973     32648           Medium

# %%
kaggle_df_lifestyle.describe()
# Out:
#               Views          Likes        Shares      Comments
# count  1.012000e+03    1012.000000   1012.000000   1012.000000
# mean   2.480989e+06  255393.247036  51367.689723  24454.609684
# std    1.464313e+06  144277.649774  28766.738235  14469.220526
# min    8.162000e+03    1256.000000     52.000000     32.000000
# 25%    1.148219e+06  129884.250000  26063.500000  11508.500000
# 50%    2.479640e+06  254264.000000  53012.000000  24522.000000
# 75%    3.705566e+06  378638.500000  76331.250000  36830.500000
# max    4.996111e+06  499312.000000  99926.000000  49993.000000

# %%
kaggle_df_fitness.describe()
# Out:
#               Views          Likes        Shares      Comments
# count  5.360000e+02     536.000000    536.000000    536.000000
# mean   2.599391e+06  253130.125000  51183.119403  24532.694030
# std    1.422014e+06  146208.885828  29003.836018  14279.231028
# min    1.236500e+04     804.000000    162.000000     85.000000
# 25%    1.525121e+06  124465.000000  27067.750000  12104.250000
# 50%    2.614428e+06  268495.000000  52395.000000  24447.500000
# 75%    3.856387e+06  369124.750000  75601.250000  36505.250000
# max    4.995243e+06  499922.000000  99759.000000  49986.000000

# %%
kaggle_df_entertainment.describe()
# Out:
#               Views          Likes        Shares      Comments
# count  1.508000e+03    1508.000000   1508.000000   1508.000000
# mean   2.449629e+06  249731.541114  50057.263263  24859.468833
# std    1.475165e+06  146164.600549  29339.407815  14143.778960
# min    4.323000e+03     957.000000     70.000000     50.000000
# 25%    1.123706e+06  123866.750000  23645.750000  12344.750000
# 50%    2.420025e+06  242742.500000  49771.000000  24718.000000
# 75%    3.727987e+06  374514.500000  75869.000000  36918.000000
# max    4.999430e+06  499664.000000  99953.000000  49951.000000

# %%
kaggle_df_fitness['Engagement_Rate'] = (kaggle_df_fitness['Likes'] + kaggle_df_fitness['Comments']) / kaggle_df_fitness['Views']

display(kaggle_df_fitness.head())
# Out:
# /tmp/ipython-input-25-752927237.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle_df_fitness['Engagement_Rate'] = (kaggle_df_fitness['Likes'] + kaggle_df_fitness['Comments']) / kaggle_df_fitness['Views']
#     Post_ID   Post_Date Platform   Hashtag Content_Type     Region    Views  \
# 13  Post_14  2022-11-08  YouTube  #Fitness         Reel      Japan  1633015
# 53  Post_54  2023-09-17  Twitter  #Fitness         Reel     Canada   392337
# 55  Post_56  2023-08-25  YouTube  #Fitness        Tweet  Australia  3934991
# 68  Post_69  2022-01-20  Twitter  #Fitness        Tweet        USA   581577
# 69  Post_70  2022-02-05  YouTube  #Fitness        Tweet  Australia  4226427
#
# ...

# %%
kaggle_df_lifestyle['Engagement_Rate'] = (kaggle_df_lifestyle['Likes'] + kaggle_df_lifestyle['Comments']) / kaggle_df_lifestyle['Views']

display(kaggle_df_lifestyle.head())
# Out:
# /tmp/ipython-input-26-1257684926.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle_df_lifestyle['Engagement_Rate'] = (kaggle_df_lifestyle['Likes'] + kaggle_df_lifestyle['Comments']) / kaggle_df_lifestyle['Views']
#     Post_ID   Post_Date   Platform     Hashtag Content_Type     Region  \
# 1    Post_2  2022-05-13  Instagram  #Education       Shorts      India
# 3    Post_4  2022-12-05    YouTube  #Education       Shorts  Australia
# 8    Post_9  2022-09-01    Twitter  #Education  Live Stream      India
# 18  Post_19  2022-05-08     TikTok    #Fashion         Post        USA
# 19  Post_20  2023-04-24    YouTube  #Education        Tweet         UK
#
#       Views   Likes  Shares  Comments Engagement_Level  Engagement_Rate
# ...

# %%
kaggle_df_entertainment['Engagement_Rate'] = (kaggle_df_entertainment['Likes'] + kaggle_df_entertainment['Comments']) / kaggle_df_entertainment['Views']

display(kaggle_df_entertainment.head())
# Out:
# /tmp/ipython-input-27-2921659656.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   kaggle_df_entertainment['Engagement_Rate'] = (kaggle_df_entertainment['Likes'] + kaggle_df_entertainment['Comments']) / kaggle_df_entertainment['Views']
#   Post_ID   Post_Date   Platform     Hashtag Content_Type     Region    Views  \
# 0  Post_1  2022-01-13     TikTok  #Challenge        Video         UK  4163464
# 2  Post_3  2022-01-07    Twitter  #Challenge        Video     Brazil  3666211
# 4  Post_5  2023-03-23     TikTok      #Dance         Post     Brazil    64866
# 5  Post_6  2022-11-23  Instagram  #Challenge       Shorts  Australia  1323566
# 6  Post_7  2022-06-09    YouTube     #Comedy        Tweet      Japan   627233
#
# ...

# %% [markdown]
# Hypothesis Questions:
#
# Engagement metrics related to content type, region, hashtags (can't do much about the fitness dataframe), and views.
#
# Correlation between variables, maybe platform and region with engagement? Maybe views and content_type with engagement?
#
# Multiple regression models based on differenet variables
#
# Share with engagement rate, with platform!

# %%
kaggle_df['Post_Date'].value_counts().sort_values()
# Out:
# Post_Date
# 2023-01-28     1
# 2022-07-02     1
# 2022-09-23     1
# 2022-12-09     1
# 2022-03-18     1
#               ..
# 2022-04-19    14
# 2022-05-25    15
# 2023-05-21    15
# 2023-02-16    16
# 2023-10-16    17
# Name: count, Length: 729, dtype: int64

# %%
kaggle_df['Post_Date'] = pd.to_datetime(kaggle_df['Post_Date'])
monthly_counts = kaggle_df['Post_Date'].dt.to_period('M').value_counts().sort_index()
display(monthly_counts)
# Out:
# Post_Date
# 2022-01    203
# 2022-02    197
# 2022-03    213
# 2022-04    182
# 2022-05    219
# 2022-06    225
# 2022-07    217
# 2022-08    215
# 2022-09    210
# 2022-10    204
# 2022-11    217
# 2022-12    220
# 2023-01    183
# 2023-02    205
# 2023-03    195
# 2023-04    213
# 2023-05    226
# 2023-06    207
# 2023-07    199
# 2023-08    207
# 2023-09    215
# 2023-10    229
# 2023-11    198
# 2023-12    201
# Freq: M, Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
monthly_counts.plot(kind='bar')
plt.title('Monthly Post Counts')
plt.xlabel('Month')
plt.ylabel('Number of Posts')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
kaggle_df['Engagement_Rate'] = (kaggle_df['Likes'] + kaggle_df['Comments']) / kaggle_df['Views']
monthly_engagement = kaggle_df.groupby(kaggle_df['Post_Date'].dt.to_period('M'))['Engagement_Rate'].mean().sort_index()
display(monthly_engagement)
# Out:
# Post_Date
# 2022-01    0.526989
# 2022-02    0.291603
# 2022-03    0.405211
# 2022-04    0.345079
# 2022-05    0.306211
# 2022-06    0.380049
# 2022-07    0.454884
# 2022-08    0.348547
# 2022-09    0.507460
# 2022-10    0.272280
# 2022-11    0.318821
# 2022-12    0.696945
# 2023-01    0.303118
# 2023-02    0.234189
# 2023-03    0.398494
# 2023-04    0.320833
# 2023-05    0.596846
# 2023-06    0.784610
# 2023-07    0.386701
# 2023-08    0.434134
# 2023-09    1.661306
# 2023-10    0.567487
# 2023-11    0.723523
# 2023-12    0.333341
# Freq: M, Name: Engagement_Rate, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
monthly_engagement.plot(kind='line')
plt.title('Average Monthly Engagement Rate')
plt.xlabel('Month')
plt.ylabel('Average Engagement Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Questions:
#
# 1. Why is there a huge peak at September 2023?
#
# 2. Why are there lows in Feb and Oct?
#
# 3. Why are there small peaks in Dec, June, and Nov?

# %%
content_type_engagement = kaggle_df.groupby('Content_Type')['Engagement_Rate'].mean().sort_values(ascending=False)
display(content_type_engagement)
# Out:
# Content_Type
# Shorts         0.734927
# Live Stream    0.518141
# Tweet          0.436437
# Reel           0.422944
# Post           0.417689
# Video          0.407217
# Name: Engagement_Rate, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
content_type_engagement.plot(kind='bar')
plt.title('Average Engagement Rate by Content Type')
plt.xlabel('Content Type')
plt.ylabel('Average Engagement Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Shorts has the maximum engagement rate, followed by live stream.
#
# What if there is a bias in live stream?

# %%
region_engagement = kaggle_df.groupby('Region')['Engagement_Rate'].mean().sort_values(ascending=False)
display(region_engagement)
# Out:
# Region
# USA          0.827822
# Canada       0.472256
# Australia    0.465677
# UK           0.455286
# Japan        0.451762
# Brazil       0.446501
# India        0.429737
# Germany      0.301298
# Name: Engagement_Rate, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
region_engagement.plot(kind='bar')
plt.title('Average Engagement Rate by Region')
plt.xlabel('Region')
plt.ylabel('Average Engagement Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# USA has almost twice as more engagement rate as any of the countries. Germany has the lowest.

# %%
hashtag_engagement = kaggle_df.groupby('Hashtag')['Engagement_Rate'].mean().sort_values(ascending=False)
display(hashtag_engagement)
# Out:
# Hashtag
# #Viral        0.933070
# #Comedy       0.559745
# #Gaming       0.513504
# #Fitness      0.465740
# #Tech         0.455945
# #Education    0.427447
# #Fashion      0.410665
# #Dance        0.394269
# #Challenge    0.385637
# #Music        0.342778
# Name: Engagement_Rate, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
hashtag_engagement.plot(kind='bar')
plt.title('Average Engagement Rate by Hashtag')
plt.xlabel('Hashtag')
plt.ylabel('Average Engagement Rate')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Viral hashtag as the most engagement  rate, while challenge hashtag has  the lowest.

# %%
kaggle_df['Post_Date'] = pd.to_datetime(kaggle_df['Post_Date'])
monthly_hashtag_engagement = kaggle_df.groupby([kaggle_df['Post_Date'].dt.to_period('M'), 'Hashtag'])['Engagement_Rate'].mean().unstack()
display(monthly_hashtag_engagement)
# Out:
# Hashtag    #Challenge   #Comedy    #Dance  #Education  #Fashion  #Fitness  \
# Post_Date
# 2022-01      0.329528  0.302187  0.112384    0.400665  2.615801  0.181127
# 2022-02      0.303569  0.167037  0.231636    0.448053  0.415704  0.203395
# 2022-03      0.406367  0.539657  0.394307    0.214676  0.361905  0.233156
# 2022-04      0.724231  0.306669  0.222837    0.208515  0.197411  0.164439
# 2022-05      0.344587  0.499692  0.460950    0.149733  0.170796  0.185048
# 2022-06      0.210091  0.138302  0.476761    0.442835  0.458102  0.830482
# 2022-07      0.409642  0.371625  0.124547    1.615457  0.272696  0.131221
# 2022-08      0.561235  0.262391  0.472039    0.325994  0.568132  0.619066
# 2022-09      0.195949  0.267467  1.200896    1.949552  0.166681  0.532436
# 2022-10      0.214748  1.133835  0.148434    0.174230  0.217899  0.276927
# 2022-11      0.312063  0.163012  1.011100    0.172964  0.130719  0.105923
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 7))
monthly_hashtag_engagement.plot(kind='line')
plt.title('Average Monthly Engagement Rate by Hashtag')
plt.xlabel('Month')
plt.ylabel('Average Engagement Rate')
plt.xticks(rotation=45)
plt.legend(title='Hashtag', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
platform_region_engagement = kaggle_df.groupby(['Platform', 'Region'])['Engagement_Rate'].mean().unstack()
display(platform_region_engagement)
# Out:
# Region     Australia    Brazil    Canada   Germany     India     Japan  \
# Platform
# Instagram   0.722692  0.734584  0.657698  0.293945  0.318935  1.001003
# TikTok      0.503061  0.327473  0.273567  0.224112  0.276488  0.364456
# Twitter     0.226975  0.495853  0.336221  0.187316  0.835131  0.271149
# YouTube     0.395718  0.251535  0.577189  0.472133  0.256739  0.286062
#
# Region           UK       USA
# Platform
# Instagram  0.398068  0.370764
# TikTok     0.314393  2.280236
# Twitter    0.516362  0.254454
# YouTube    0.588733  0.574555

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 8))
sns.heatmap(platform_region_engagement, annot=True, fmt=".2f", cmap="YlGnBu")
plt.title('Average Engagement Rate by Platform and Region')
plt.xlabel('Region')
plt.ylabel('Platform')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", message="No supported index is set.")
warnings.filterwarnings("ignore", message="A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.")


# Ensure the index is a proper PeriodIndex with frequency
monthly_engagement.index = monthly_engagement.index.to_timestamp()
monthly_engagement
# Out:
# Post_Date
# 2022-01-01    0.526989
# 2022-02-01    0.291603
# 2022-03-01    0.405211
# 2022-04-01    0.345079
# 2022-05-01    0.306211
# 2022-06-01    0.380049
# 2022-07-01    0.454884
# 2022-08-01    0.348547
# 2022-09-01    0.507460
# 2022-10-01    0.272280
# 2022-11-01    0.318821
# 2022-12-01    0.696945
# 2023-01-01    0.303118
# 2023-02-01    0.234189
# 2023-03-01    0.398494
# 2023-04-01    0.320833
# 2023-05-01    0.596846
# 2023-06-01    0.784610
# 2023-07-01    0.386701
# 2023-08-01    0.434134
# 2023-09-01    1.661306
# 2023-10-01    0.567487
# 2023-11-01    0.723523
# 2023-12-01    0.333341
# Freq: MS, Name: Engagement_Rate, dtype: float64

# %%
import pandas as pd
from statsmodels.tsa.arima.model import ARIMA
import warnings

# Suppress specific warnings
warnings.filterwarnings("ignore", message="No supported index is set.")
warnings.filterwarnings("ignore", message="A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.")


# Ensure the index is a proper PeriodIndex with frequency
monthly_engagement
# Fit a simple ARIMA model
# The order (p, d, q) is a common starting point, but would typically be determined through analysis
model = ARIMA(monthly_engagement, order=(5,1,0))
model_fit = model.fit()

# Print the model summary
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ...
# Dep. Variable:        Engagement_Rate   No. Observations:                   24
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                  -4.681
# Date:                Fri, 27 Jun 2025   AIC                             21.361
# Time:                        03:32:00   BIC                             28.174
# Sample:                    01-01-2022   HQIC                            23.075
#                          - 12-01-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.9884      1.356     -0.729      0.466      -3.645       1.669
# ar.L2         -0.8661      1.442     -0.601      0.548      -3.691       1.959
# ar.L3         -0.6686      1.426     -0.469      0.639      -3.463       2.126
# ...

# %%
# Identify months with highest and lowest overall engagement
highest_engagement_month = monthly_engagement.idxmax()
lowest_engagement_month = monthly_engagement.idxmin()

print(f"Month with highest overall engagement: {highest_engagement_month}")
print(f"Month with lowest overall engagement: {lowest_engagement_month}")

# Display hashtag engagement for the highest engagement month
print(f"\nHashtag engagement in {highest_engagement_month}:")
display(monthly_hashtag_engagement.loc[highest_engagement_month])

# Display hashtag engagement for the lowest engagement month
print(f"\nHashtag engagement in {lowest_engagement_month}:")
display(monthly_hashtag_engagement.loc[lowest_engagement_month])
# Out:
# Month with highest overall engagement: 2023-09-01 00:00:00
# Month with lowest overall engagement: 2023-02-01 00:00:00
#
# Hashtag engagement in 2023-09-01 00:00:00:
# Hashtag
# #Challenge     0.182013
# #Comedy        0.193016
# #Dance         0.178692
# #Education     0.193199
# #Fashion       0.207027
# #Fitness       0.828257
# #Gaming        0.846986
# #Music         0.468596
# #Tech          0.161208
# #Viral        11.482299
# Name: 2023-09, dtype: float64
# Hashtag engagement in 2023-02-01 00:00:00:
# Hashtag
# #Challenge    0.244445
# #Comedy       0.701611
# #Dance        0.190931
# #Education    0.127804
# #Fashion      0.137986
# #Fitness      0.319713
# #Gaming       0.130469
# #Music        0.222170
# #Tech         0.178309
# #Viral        0.199782
# Name: 2023-02, dtype: float64

# %%
# Display hashtag engagement for December 2022
print("Hashtag engagement in December 2022:")
display(monthly_hashtag_engagement.loc['2022-12'])

# Display hashtag engagement for June 2023
print("\nHashtag engagement in June 2023:")
display(monthly_hashtag_engagement.loc['2023-06'])

# Display hashtag engagement for November 2023
print("\nHashtag engagement in November 2023:")
display(monthly_hashtag_engagement.loc['2023-11'])
# Out:
# Hashtag engagement in December 2022:
# Hashtag
# #Challenge    0.200035
# #Comedy       2.091918
# #Dance        0.226759
# #Education    0.226774
# #Fashion      0.498823
# #Fitness      0.176877
# #Gaming       0.851623
# #Music        0.287610
# #Tech         0.253391
# #Viral        1.708695
# Name: 2022-12, dtype: float64
# Hashtag engagement in June 2023:
# Hashtag
# #Challenge    0.138645
# #Comedy       0.452450
# #Dance        0.379392
# #Education    0.251798
# #Fashion      0.446007
# #Fitness      1.663151
# #Gaming       0.183925
# #Music        0.116814
# #Tech         3.381376
# #Viral        0.169441
# Name: 2023-06, dtype: float64
# Hashtag engagement in November 2023:
# Hashtag
# #Challenge    0.172081
# #Comedy       4.002775
# #Dance        0.195728
# #Education    0.578436
# #Fashion      0.311015
# #Fitness      0.440540
# #Gaming       0.218168
# #Music        0.269608
# #Tech         0.238173
# #Viral        0.799809
# Name: 2023-11, dtype: float64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# Perform additive decomposition
decomposition = seasonal_decompose(monthly_engagement, model='additive')

# Plot the decomposed components
fig = decomposition.plot()
fig.set_size_inches(10, 8)
plt.tight_layout()
plt.show()

# %% [markdown]
# Shorts has the maximum engagement rate, followed by live stream.
#
# What if there is a bias in live stream?
#
# Viral hashtag as the most engagement  rate, while challenge hashtag has  the lowest.
#
# USA has almost twice as more engagement rate as any of the countries. Germany has the lowest.
